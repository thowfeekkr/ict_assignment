# %% [markdown]
# <a href="https://colab.research.google.com/github/thowfeekkr/ict_assignment/blob/main/assignment03_thowfeekkr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # assignment 3

# %% [markdown]
# q1

# %%
n1 = float(input(" enter 1st numbers: "))
n2 = float(input("enter 2nd number :"))
n3 = float(input("Enter 3rd number: "))
nm = max(n1,n2,n3 )
print(nm)
# Out:
#  enter 1st numbers: 50
# enter 2nd number :200
# Enter 3rd number: 300
# 300.0

# %% [markdown]
# q2

# %%
number =[1,2,3,4,5]
total = sum(number)
print(total)
# Out:
# 15

# %% [markdown]
# **q3**

# %%
num = [10,20,30,40,50]
n1=int(input("Enter the number you want to insert: "))
pos = int(input("Enter the position in the list: "))
num.insert(pos,n1)
print(num)
# Out:
# Enter the number you want to insert: 60
# Enter the position in the list: 5
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# **q4**

# %%
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}

# %%
sample_dict['city'] = "chalakudy"

# %%
sample_dict
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'city': 'chalakudy'}

# %% [markdown]
# q5

# %%
sample_dict1 = {
 'emp1': {'name': 'Jhon', 'salary': 7500},
 'emp2': {'name': 'Emma', 'salary': 8000},
 'emp3': {'name': 'Brad', 'salary': 500}
}

# %%
sample_dict1['emp3']['salary'] = 8500

# %%
sample_dict1
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500},
#  'emp2': {'name': 'Emma', 'salary': 8000},
#  'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# q6

# %%
 tuple1 = (11, 22, 33, 44, 55, 66)

# %%
tuple2 = tuple1[3:5]

# %%
tuple2
# Out:
# (44, 55)

# %% [markdown]
# q7

# %%
 tuple1 = (50,10,60,70,50,83,567,50,81)

# %%
tuple1.count(50)
# Out:
# 3
